# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../DataProcessed/sample.csv')

# %%
plt.figure()
plt.plot(np.arange(len(df['WND_speed'])), df['WND_speed'])
